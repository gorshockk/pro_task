# %%
from sklearn import tree
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import plot_tree

train_df=pd.read_parquet('../train.parquet')
test_df=pd.read_parquet('../test.parquet')
train_df
# Out:
#           id                                              dates  \
# 0      19114  [2016-01-01, 2016-02-01, 2016-03-01, 2016-04-0...
# 1      22769  [2016-05-01, 2016-06-01, 2016-07-01, 2016-08-0...
# 2      76935  [2017-03-01, 2017-04-01, 2017-05-01, 2017-06-0...
# 3      66297  [2016-01-01, 2016-02-01, 2016-03-01, 2016-04-0...
# 4       2191  [2016-01-01, 2016-02-01, 2016-03-01, 2016-04-0...
# ...      ...                                                ...
# 79995  71474  [2018-10-01, 2018-11-01, 2018-12-01, 2019-01-0...
# 79996  36908  [2016-07-01, 2016-08-01, 2016-09-01, 2016-10-0...
# 79997  63517  [2016-03-01, 2016-04-01, 2016-05-01, 2016-06-0...
# 79998  94731  [2016-02-01, 2016-03-01, 2016-04-01, 2016-05-0...
# 79999  98870  [2016-01-01, 2016-02-01, 2016-03-01, 2016-04-0...
#
#                                                   values  label
# 0      [-1.86, 0.79, 1.4, 0.15, 0.0, -1.24, -1.46, 3....    0.0
# 1      [-1.04, -3.48, 0.05, -0.13, -0.01, 0.03, 0.27,...    1.0
# ...

# %%
a=train_df.iloc[::,1].apply(len)==train_df.iloc[::,2].apply(len)
a[a==False]
#количестово дат = количеству значений
# Out:
# Series([], dtype: bool)

# %%
id=train_df.groupby('id').size()
id[id>1]
#нет повторяющихся id
# Out:
# Series([], dtype: int64)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      80000 non-null  int64
#  1   dates   80000 non-null  object
#  2   values  80000 non-null  object
#  3   label   80000 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
train_df.describe()
# Out:
#                  id         label
# count  80000.000000  80000.000000
# mean   50107.893162      0.277250
# std    28857.649778      0.447644
# min        0.000000      0.000000
# 25%    25122.500000      0.000000
# 50%    50146.500000      0.000000
# 75%    75064.250000      1.000000
# max    99999.000000      1.000000

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20000 non-null  int64
#  1   dates   20000 non-null  object
#  2   values  20000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 468.9+ KB

# %%
test_df.describe()
# Out:
#                  id
# count  20000.000000
# mean   49565.927350
# std    28904.312706
# min        2.000000
# 25%    24497.250000
# 50%    49399.000000
# 75%    74769.250000
# max    99985.000000

# %%
train_df.isnull().sum()
# Out:
# id        0
# dates     0
# values    0
# label     0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# id        0
# dates     0
# values    0
# dtype: int64

# %%
#сделаем так,чтобы каждая дата равнялась одному значени. и занесем в строку
#данных слишком много следовательно нужно их как то урезать.колонка dates составлять 62 образца за каждый месяц с 2016 по 2021
#сделаем меньше-возьмем значения за каждый год и посчитаем среднее

# %%
def mean_values(row):
    means=[]
    for i in range(0,60,12):
        mean=round(np.mean(row[i:i+12]),2)
        means.append(mean)
    return means

# %%
def explode_columns(df):
    a=['dates','values']
    return df.explode(a).reset_index(drop=True)

# %%
batch_size=10000
n_batches=len(train)//batch_size
all_batch=[]
for i in range(n_batches):
    batch=train.iloc[i*batch_size:+i*batch_size+batch_size]
    batch_explode=explode_columns(batch)
    batch_explode['dates']=pd.to_datetime(batch_explode['dates'])
    batch_explode['year'] = batch_explode['dates'].dt.year
    avg_batch=batch_explode.groupby(['id', 'year','label'])['values'].mean().reset_index()
    all_batch.append(avg_batch)

# %%
train=pd.concat(all_batch)

# %%
train=train[['id','year','values','label']]
train
# Out:
#           id  year    values  label
# 0         44  2016  0.186364    0.0
# 1         44  2017 -0.043333    0.0
# 2         44  2018 -0.268333    0.0
# 3         44  2019      0.18    0.0
# 4         44  2020      1.05    0.0
# ...      ...   ...       ...    ...
# 59584  99984  2017  0.001667    0.0
# 59585  99984  2018  0.224167    0.0
# 59586  99984  2019  0.268333    0.0
# 59587  99984  2020     0.505    0.0
# 59588  99984  2021    0.3125    0.0
#
# [477309 rows x 4 columns]

# %%
train['values']=train['values'].astype(float)

# %%
train.describe()
# Out:
#                   id           year         values          label
# count  477309.000000  477309.000000  476861.000000  477309.000000
# mean    50094.522175    2018.905028      -0.034926       0.273443
# std     28859.091644       1.964551       0.643159       0.445727
# min         0.000000    2016.000000      -6.630000       0.000000
# 25%     25106.000000    2017.000000      -0.405833       0.000000
# 50%     50131.000000    2019.000000      -0.031667       0.000000
# 75%     75045.000000    2020.000000       0.343333       1.000000
# max     99999.000000    2024.000000       8.880000       1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477309 entries, 0 to 59588
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      477309 non-null  int64
#  1   year    477309 non-null  int32
#  2   values  476861 non-null  float64
#  3   label   477309 non-null  float64
# dtypes: float64(2), int32(1), int64(1)
# memory usage: 16.4 MB

# %%
train = train.reset_index(drop=True)
train
# Out:
#            id  year    values  label
# 0          44  2016  0.186364    0.0
# 1          44  2017 -0.043333    0.0
# 2          44  2018 -0.268333    0.0
# 3          44  2019  0.180000    0.0
# 4          44  2020  1.050000    0.0
# ...       ...   ...       ...    ...
# 477304  99984  2017  0.001667    0.0
# 477305  99984  2018  0.224167    0.0
# 477306  99984  2019  0.268333    0.0
# 477307  99984  2020  0.505000    0.0
# 477308  99984  2021  0.312500    0.0
#
# [477309 rows x 4 columns]

# %%
train=train[train['year']!=2024]

# %%
sns.histplot(data=train, x='values', hue='year', multiple='stack')
# Out:
# <Axes: xlabel='values', ylabel='Count'>

# %%
sns.countplot(x="label",data=train)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
sns.lineplot(x='year',y='values',data=train,hue='label')
# Out:
# <Axes: xlabel='year', ylabel='values'>

# %%
sns.stripplot(x="year",y="values",data=train,hue='label')
# Out:
# <Axes: xlabel='year', ylabel='values'>

# %%
sns.boxplot(x='year',y='values',hue='label',data=train)
# Out:
# <Axes: xlabel='year', ylabel='values'>

# %%
corr_matrix = train.corr()
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# <h2>Обучение модели<h2>

# %%
#считаю среднее для тест 
test=test_df.copy()
batch_size=10000
n_batches=len(test)//batch_size
all_batch=[]
for i in range(n_batches):
    batch=test.iloc[i*batch_size:+i*batch_size+batch_size]
    batch_explode=explode_columns(batch)
    batch_explode['dates']=pd.to_datetime(batch_explode['dates'])
    batch_explode['year'] = batch_explode['dates'].dt.year
    avg_batch=batch_explode.groupby(['id', 'year'])['values'].mean().reset_index()
    all_batch.append(avg_batch)

# %%
test=pd.concat(all_batch)

# %%
test['values']=test['values'].astype(float)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119188 entries, 0 to 59544
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      119188 non-null  int64
#  1   year    119188 non-null  int32
#  2   values  119082 non-null  float64
# dtypes: float64(1), int32(1), int64(1)
# memory usage: 3.2 MB

# %%
def split_data(X,y):
    train_size=int(len(X)*0.67)
    X_train=X.iloc[0:train_size]
    y_train=y.iloc[0:train_size]
    X_test=X.iloc[train_size:]
    y_test=y.iloc[train_size:]
    return X_train,X_test,y_train,y_test

# %%
X=train.drop(columns=['label'])
y=train.label

# %%
X_train,X_test,y_train,y_test=split_data(X,y)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
boost_params={"n_estimators":range(200,300,10),
             "max_depth":[6,10,12],
             "learning_rate":[0.05,0.1]}
clf=XGBClassifier(random_state=42)
Random_Search = RandomizedSearchCV(clf, boost_params, n_iter=7, cv=3)

# %%
Random_Search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            max_cat_threshold=None,
# ...

# %%
Random_Search.best_params_
# Out:
# {'n_estimators': 220, 'max_depth': 6, 'learning_rate': 0.05}

# %%
best_clf=XGBClassifier(n_estimators= 220, max_depth = 6, learning_rate= 0.05,random_state=42)

# %%
best_clf.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=220, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
best_clf.score(X_train,y_train)
# Out:
# 0.7392578431065283

# %%
best_clf.score(X_test,y_test)
# Out:
# 0.736704124616618

# %%
best_clf.predict_proba(X_test)[:,0]
# Out:
# array([0.74057853, 0.78946865, 0.77642334, ..., 0.725324  , 0.78259933,
#        0.81096673], dtype=float32)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, best_clf.predict_proba(X_test)[:,1])
# Out:
# 0.6021018204705819
